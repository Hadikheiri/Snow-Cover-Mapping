# %%
from snow_processing import check_all_products_side_by_side
import pandas as pd

# Define your raw input folders
product_folders = [
    ("MODIS", r"F:\GeoinformaticsProject\Data\MODIS_SnowMask\2022", False),
    ("MODIS", r"F:\GeoinformaticsProject\Data\MODIS_SnowMask\2023", False),
    ("GFSC",  r"F:\GeoinformaticsProject\Data\GFSC\GFSC", True),
    ("S2",    r"F:\GeoinformaticsProject\Data\S2\S2\SnowMask", False),
    ("S3",    r"F:\GeoinformaticsProject\Data\S3\S3\SnowMask", False),
]

# Run the check
df = check_all_products_side_by_side(product_folders, start_year=2022, end_year=2023)

# Show all weeks
pd.set_option("display.max_rows", None)
display(df)
# Out:
# 🔍 Scanning MODIS → F:\GeoinformaticsProject\Data\MODIS_SnowMask\2022
#    ➤ Found 15 unique weeks
# 🔍 Scanning MODIS → F:\GeoinformaticsProject\Data\MODIS_SnowMask\2023
#    ➤ Found 18 unique weeks
# 🔍 Scanning GFSC → F:\GeoinformaticsProject\Data\GFSC\GFSC
#    ➤ Found 51 unique weeks
# 🔍 Scanning S2 → F:\GeoinformaticsProject\Data\S2\S2\SnowMask
#    ➤ Found 31 unique weeks
# 🔍 Scanning S3 → F:\GeoinformaticsProject\Data\S3\S3\SnowMask
#    ➤ Found 40 unique weeks
#          Week MODIS GFSC S2 S3 Common_Week
# 0    2022_W01     ❌    ✅  ✅  ✅
# 1    2022_W02     ✅    ✅  ❌  ✅
# 2    2022_W03     ❌    ✅  ✅  ✅
# 3    2022_W04     ✅    ✅  ❌  ✅
# 4    2022_W05     ❌    ✅  ✅  ✅
# 5    2022_W06     ✅    ✅  ❌  ✅
# 6    2022_W07     ✅    ✅  ✅  ✅           ✅
# 7    2022_W08     ✅    ✅  ❌  ✅
# 8    2022_W09     ✅    ✅  ✅  ✅           ✅
# 9    2022_W10     ✅    ✅  ❌  ✅
# 10   2022_W11     ✅    ✅  ✅  ✅           ✅
# 11   2022_W12     ✅    ✅  ❌  ✅
# 12   2022_W13     ❌    ✅  ✅  ❌
# 13   2022_W14     ✅    ✅  ❌  ❌
# 14   2022_W15     ❌    ✅  ✅  ❌
# 15   2022_W16     ✅    ✅  ❌  ❌
# 16   2022_W17     ✅    ❌  ❌  ❌
# 17   2022_W18     ❌    ❌  ❌  ❌
# 18   2022_W19     ✅    ❌  ❌  ❌
# 19   2022_W20     ❌    ❌  ❌  ❌
# 20   2022_W21     ❌    ❌  ❌  ❌
# 21   2022_W22     ❌    ❌  ❌  ❌
# 22   2022_W23     ❌    ❌  ❌  ❌
# 23   2022_W24     ❌    ❌  ❌  ❌
# 24   2022_W25     ❌    ❌  ❌  ❌
# 25   2022_W26     ❌    ❌  ❌  ❌
# 26   2022_W27     ❌    ❌  ❌  ❌
# 27   2022_W28     ❌    ❌  ❌  ❌
# 28   2022_W29     ❌    ❌  ❌  ❌
# 29   2022_W30     ❌    ❌  ❌  ❌
# 30   2022_W31     ❌    ❌  ❌  ❌
# 31   2022_W32     ❌    ❌  ❌  ❌
# 32   2022_W33     ❌    ❌  ❌  ❌
# 33   2022_W34     ❌    ❌  ❌  ❌
# 34   2022_W35     ❌    ❌  ❌  ❌
# 35   2022_W36     ❌    ❌  ❌  ❌
# 36   2022_W37     ❌    ❌  ❌  ❌
# 37   2022_W38     ❌    ❌  ❌  ❌
# 38   2022_W39     ❌    ❌  ❌  ❌
# 39   2022_W40     ❌    ❌  ✅  ✅
# 40   2022_W41     ❌    ❌  ❌  ✅
# 41   2022_W42     ❌    ❌  ✅  ✅
# 42   2022_W43     ✅    ❌  ❌  ✅
# 43   2022_W44     ✅    ✅  ✅  ✅           ✅
# 44   2022_W45     ❌    ✅  ❌  ✅
# 45   2022_W46     ❌    ✅  ✅  ✅
# 46   2022_W47     ✅    ✅  ❌  ✅
# 47   2022_W48     ❌    ✅  ✅  ✅
# 48   2022_W49     ✅    ✅  ✅  ✅           ✅
# 49   2022_W50     ✅    ✅  ✅  ✅           ✅
# 50   2022_W51     ❌    ✅  ❌  ✅
# 51   2022_W52     ✅    ✅  ✅  ❌
# 52   2022_W53     ❌    ❌  ❌  ❌
# 53   2023_W01     ❌    ✅  ❌  ❌
# 54   2023_W02     ✅    ✅  ✅  ❌
# 55   2023_W03     ❌    ✅  ✅  ✅
# 56   2023_W04     ✅    ✅  ✅  ✅           ✅
# 57   2023_W05     ❌    ✅  ✅  ✅
# 58   2023_W06     ✅    ✅  ✅  ✅           ✅
# 59   2023_W07     ❌    ✅  ✅  ✅
# 60   2023_W08     ✅    ✅  ✅  ✅           ✅
# 61   2023_W09     ✅    ✅  ✅  ✅           ✅
# 62   2023_W10     ✅    ✅  ✅  ✅           ✅
# 63   2023_W11     ✅    ✅  ✅  ✅           ✅
# 64   2023_W12     ❌    ✅  ✅  ✅
# 65   2023_W13     ✅    ✅  ✅  ✅           ✅
# 66   2023_W14     ✅    ✅  ✅  ✅           ✅
# 67   2023_W15     ✅    ✅  ✅  ✅           ✅
# 68   2023_W16     ❌    ✅  ❌  ✅
# 69   2023_W17     ✅    ✅  ✅  ✅           ✅
# 70   2023_W18     ✅    ❌  ❌  ✅
# 71   2023_W19     ❌    ❌  ❌  ❌
# 72   2023_W20     ❌    ❌  ❌  ❌
# 73   2023_W21     ❌    ❌  ❌  ❌
# 74   2023_W22     ❌    ❌  ❌  ❌
# 75   2023_W23     ❌    ❌  ❌  ❌
# 76   2023_W24     ❌    ❌  ❌  ❌
# 77   2023_W25     ❌    ❌  ❌  ❌
# 78   2023_W26     ❌    ❌  ❌  ❌
# 79   2023_W27     ❌    ❌  ❌  ❌
# 80   2023_W28     ❌    ❌  ❌  ❌
# 81   2023_W29     ❌    ❌  ❌  ❌
# 82   2023_W30     ❌    ❌  ❌  ❌
# 83   2023_W31     ❌    ❌  ❌  ❌
# 84   2023_W32     ❌    ❌  ❌  ❌
# 85   2023_W33     ❌    ❌  ❌  ❌
# 86   2023_W34     ❌    ❌  ❌  ❌
# 87   2023_W35     ❌    ❌  ❌  ❌
# 88   2023_W36     ❌    ❌  ❌  ❌
# 89   2023_W37     ❌    ❌  ❌  ❌
# 90   2023_W38     ❌    ❌  ❌  ❌
# 91   2023_W39     ❌    ❌  ❌  ❌
# 92   2023_W40     ❌    ❌  ❌  ❌
# 93   2023_W41     ❌    ❌  ❌  ❌
# 94   2023_W42     ❌    ❌  ❌  ❌
# 95   2023_W43     ❌    ❌  ❌  ❌
# 96   2023_W44     ❌    ❌  ❌  ❌
# 97   2023_W45     ❌    ❌  ❌  ❌
# 98   2023_W46     ❌    ❌  ❌  ❌
# 99   2023_W47     ❌    ❌  ❌  ❌
# 100  2023_W48     ❌    ❌  ❌  ❌
# 101  2023_W49     ❌    ❌  ❌  ❌
# 102  2023_W50     ❌    ❌  ❌  ❌
# 103  2023_W51     ❌    ❌  ❌  ❌
# 104  2023_W52     ❌    ❌  ❌  ❌
# 105  2023_W53     ❌    ❌  ❌  ❌

# %%
# Step 1: Re-import the weekly product coverage table
from snow_processing import check_all_products_side_by_side

product_folders = [
    ("MODIS", r"F:\GeoinformaticsProject\Data\MODIS_SnowMask\2022", False),
    ("MODIS", r"F:\GeoinformaticsProject\Data\MODIS_SnowMask\2023", False),
    ("GFSC",  r"F:\GeoinformaticsProject\Data\GFSC\GFSC", True),
    ("S2",    r"F:\GeoinformaticsProject\Data\S2\S2\SnowMask", False),
    ("S3",    r"F:\GeoinformaticsProject\Data\S3\S3\SnowMask", False),
]

# Run the week check
df = check_all_products_side_by_side(product_folders, start_year=2022, end_year=2023)

# Step 2: Prepare the data for heatmap
import matplotlib.pyplot as plt
import seaborn as sns

heatmap_df = df.copy()
products = [col for col in heatmap_df.columns if col not in ["Week", "Common_Week"]]

for col in products:
    heatmap_df[col] = heatmap_df[col].map({'✅': 1, '❌': 0})

heatmap_matrix = heatmap_df.set_index("Week")[products]

# Step 3: Plot heatmap
plt.figure(figsize=(10, len(heatmap_matrix) // 3))
sns.heatmap(
    heatmap_matrix,
    cmap="YlGnBu",
    cbar=True,
    linewidths=0.3,
    linecolor='gray',
    square=False
)

plt.title("🧊 Weekly Availability of Snow Products (2022–2023)", fontsize=14)
plt.xlabel("Product")
plt.ylabel("ISO Week")
plt.tight_layout()
plt.show()
# Out:
# 🔍 Scanning MODIS → F:\GeoinformaticsProject\Data\MODIS_SnowMask\2022
#    ➤ Found 15 unique weeks
# 🔍 Scanning MODIS → F:\GeoinformaticsProject\Data\MODIS_SnowMask\2023
#    ➤ Found 18 unique weeks
# 🔍 Scanning GFSC → F:\GeoinformaticsProject\Data\GFSC\GFSC
#    ➤ Found 51 unique weeks
# 🔍 Scanning S2 → F:\GeoinformaticsProject\Data\S2\S2\SnowMask
#    ➤ Found 31 unique weeks
# 🔍 Scanning S3 → F:\GeoinformaticsProject\Data\S3\S3\SnowMask
#    ➤ Found 40 unique weeks
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18844\3116371220.py:41: UserWarning: Glyph 129482 (\N{ICE CUBE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Users\Lenovo\anaconda3\envs\geop_env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 129482 (\N{ICE CUBE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import os
from rasterio.enums import Resampling
from snow_processing import reproject_resample_visualize, aggregate_weekly

# === Step 1: Reproject & Resample all .img files from 2022 and 2023 ===

input_base = r"F:\GeoinformaticsProject\Data\MODIS_SnowMask"
resampled_output = r"F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\MODIS"
os.makedirs(resampled_output, exist_ok=True)

# Loop through both years
for year in ['2022', '2023']:
    year_path = os.path.join(input_base, year)
    for fname in os.listdir(year_path):
        if fname.endswith('.img') and fname.startswith('neve_'):
            src_path = os.path.join(year_path, fname)
            base_name = os.path.splitext(fname)[0]
            dst_name = f"RR-{base_name}.tif"
            dst_path = os.path.join(resampled_output, dst_name)

            reproject_resample_visualize(
                src_path=src_path,
                dst_path=dst_path,
                dst_crs='EPSG:32632',
                dst_res=(20, 20),
                resampling_method=Resampling.nearest,
                visualize=False
            )
# Out:
# f:\GeoinformaticsProject\Code\snow_processing.py:40: SyntaxWarning: invalid escape sequence '\M'
#   """
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 21
#      18             dst_name = f"RR-{base_name}.tif"
#      19             dst_path = os.path.join(resampled_output, dst_name)
# ---> 21             reproject_resample_visualize(
#      22                 src_path=src_path,
#      23                 dst_path=dst_path,
#      24                 dst_crs='EPSG:32632',
#      25                 dst_res=(20, 20),
#      26                 resampling_method=Resampling.nearest,
#      27                 visualize=False
#      28             )
#      30 # === Step 2: Weekly Aggregation ===
#      32 weekly_output = r"F:\GeoinformaticsProject\Data\Processed\WEEKLY\MODIS"
#
# File f:\GeoinformaticsProject\Code\snow_processing.py:133, in reproject_resample_visualize(src_path, dst_path, dst_crs, dst_res, resampling_method, visualize, downsample_factor)
#     122 kwargs.update({
#     123     'driver': 'GTiff',
#     124     'crs': dst_crs,
#    (...)
#     129     'count': src.count
#     130 })
#     132 # Perform reprojection and save output
# --> 133 with rasterio.open(dst_path, 'w', **kwargs) as dst:
#     134     for i in range(1, src.count + 1):
#     135         reproject(
#     136             source=rasterio.band(src, i),
#     137             destination=rasterio.band(dst, i),
#    (...)
#     142             resampling=resampling_method
#     143         )
#
# File rasterio\\_base.pyx:450, in rasterio._base.DatasetBase.__exit__()
#
# File rasterio\\_base.pyx:441, in rasterio._base.DatasetBase.close()
#
# File c:\Users\Lenovo\anaconda3\envs\geop_env\Lib\contextlib.py:627, in ExitStack.close(self)
#     625 def close(self):
#     626     """Immediately unwind the context stack."""
# --> 627     self.__exit__(None, None, None)
#
# File c:\Users\Lenovo\anaconda3\envs\geop_env\Lib\contextlib.py:571, in ExitStack.__exit__(self, *exc_details)
#     568 def __enter__(self):
#     569     return self
# --> 571 def __exit__(self, *exc_details):
#     572     exc = exc_details[1]
#     573     received_exc = exc is not None
#
# KeyboardInterrupt:

# %%
import os
from snow_processing import aggregate_weekly

resampled_modis = r"F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\MODIS"
weekly_modis   = r"F:\GeoinformaticsProject\Data\Processed\WEEKLY\MODIS"

print("\n▶️ Aggregating weekly for MODIS")
aggregate_weekly(
    directory     = resampled_modis,
    pattern       = '.tif',      # all binary MODIS .tif files
    output_dir    = weekly_modis,
    method        = 'max',
    threshold     = None,        # keep raw 0/1
    qc_suffix     = '_QC.tif',   # no effect (no QC files)
    skip_existing = False,
    summary       = True,
    parallel      = True,
    max_workers   = 1
)
# Out:
# ▶️ Aggregating weekly for MODIS
# 📦 Aggregating 1 → 2021_W51 (max)
# 📦 Aggregating 2 → 2022_W52 (max)
# 📦 Aggregating 2 → 2022_W02 (max)
# 📦 Aggregating 2 → 2022_W04 (max)
# 📦 Aggregating 1 → 2022_W06 (max)
# 📦 Aggregating 1 → 2022_W07 (max)
# 📦 Aggregating 1 → 2022_W08 (max)
# 📦 Aggregating 1 → 2022_W09 (max)
# 📦 Aggregating 1 → 2022_W10 (max)
# 📦 Aggregating 1 → 2022_W11 (max)
# 📦 Aggregating 2 → 2022_W12 (max)
# 📦 Aggregating 2 → 2022_W14 (max)
# 📦 Aggregating 1 → 2022_W16 (max)
# 📦 Aggregating 1 → 2022_W17 (max)
# 📦 Aggregating 1 → 2022_W19 (max)
# 📦 Aggregating 1 → 2022_W43 (max)
# 📦 Aggregating 1 → 2022_W44 (max)
# 📦 Aggregating 1 → 2022_W47 (max)
# 📦 Aggregating 1 → 2022_W49 (max)
# 📦 Aggregating 2 → 2022_W50 (max)
# 📦 Aggregating 1 → 2023_W02 (max)
# 📦 Aggregating 1 → 2023_W04 (max)
# 📦 Aggregating 2 → 2023_W06 (max)
# 📦 Aggregating 1 → 2023_W08 (max)
# 📦 Aggregating 1 → 2023_W09 (max)
# 📦 Aggregating 1 → 2023_W10 (max)
# 📦 Aggregating 1 → 2023_W11 (max)
# 📦 Aggregating 1 → 2023_W13 (max)
# 📦 Aggregating 1 → 2023_W14 (max)
# 📦 Aggregating 2 → 2023_W15 (max)
# 📦 Aggregating 1 → 2023_W17 (max)
# 📦 Aggregating 1 → 2023_W18 (max)
# ✔️ Processed: 32, ⏭ Skipped: 0, Outputs: 32
# ['F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\MODIS\\2021_W51.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\MODIS\\2022_W52.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\MODIS\\2022_W02.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\MODIS\\2022_W04.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\MODIS\\2022_W06.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\MODIS\\2022_W07.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\MODIS\\2022_W08.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\MODIS\\2022_W09.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\MODIS\\2022_W10.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\MODIS\\2022_W11.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\MODIS\\2022_W12.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\MODIS\\2022_W14.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\MODIS\\2022_W16.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\MODIS\\2022_W17.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\MODIS\\2022_W19.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\MODIS\\2022_W43.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\MODIS\\2022_W44.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\MODIS\\2022_W47.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\MODIS\\2022_W49.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\MODIS\\2022_W50.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\MODIS\\2023_W02.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\MODIS\\2023_W04.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\MODIS\\2023_W06.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\MODIS\\2023_W08.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\MODIS\\2023_W09.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\MODIS\\2023_W10.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\MODIS\\2023_W11.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\MODIS\\2023_W13.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\MODIS\\2023_W14.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\MODIS\\2023_W15.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\MODIS\\2023_W17.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\MODIS\\2023_W18.tif']

# %%
import os
import rasterio
import numpy as np
import pandas as pd
from datetime import datetime

modis_dir = r"F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\MODIS"
summary = []

for fname in os.listdir(modis_dir):
    if not fname.endswith('.tif'):
        continue
    path = os.path.join(modis_dir, fname)
    try:
        with rasterio.open(path) as src:
            data = src.read(1)
            nodata = src.nodata
            valid_pixels = np.sum(data != nodata)
            unique_vals = np.unique(data)
            size_kb = os.path.getsize(path) / 1024

        date_str = ''.join([c for c in fname if c.isdigit()])[:8]
        date = pd.to_datetime(date_str, format="%Y%m%d", errors='coerce')
        week = date.isocalendar().week if date is not pd.NaT else 'Unknown'

        summary.append({
            "filename": fname,
            "size_kb": round(size_kb, 1),
            "shape": data.shape,
            "unique_values": unique_vals.tolist(),
            "valid_pixels": int(valid_pixels),
            "week": week
        })

    except Exception as e:
        summary.append({
            "filename": fname,
            "error": str(e)
        })

df = pd.DataFrame(summary)
print(df.to_string())
# Out:
#                 filename   size_kb           shape unique_values  valid_pixels  week
# 0   RR-neve_20211220.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506    51
# 1   RR-neve_20220101.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506    52
# 2   RR-neve_20220111.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506     2
# 3   RR-neve_20220116.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506     2
# 4   RR-neve_20220124.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506     4
# 5   RR-neve_20220130.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506     4
# 6   RR-neve_20220209.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506     6
# 7   RR-neve_20220217.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506     7
# 8   RR-neve_20220222.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506     8
# 9   RR-neve_20220228.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506     9
# 10  RR-neve_20220309.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506    10
# 11  RR-neve_20220320.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506    11
# 12  RR-neve_20220322.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506    12
# 13  RR-neve_20220326.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506    12
# 14  RR-neve_20220405.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506    14
# 15  RR-neve_20220410.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506    14
# 16  RR-neve_20220418.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506    16
# 17  RR-neve_20220427.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506    17
# 18  RR-neve_20220513.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506    19
# 19  RR-neve_20221029.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506    43
# 20  RR-neve_20221105.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506    44
# 21  RR-neve_20221126.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506    47
# 22  RR-neve_20221207.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506    49
# 23  RR-neve_20221212.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506    50
# 24  RR-neve_20221217.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506    50
# 25  RR-neve_20221227.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506    52
# 26  RR-neve_20230110.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506     2
# 27  RR-neve_20230129.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506     4
# 28  RR-neve_20230207.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506     6
# 29  RR-neve_20230212.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506     6
# 30  RR-neve_20230221.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506     8
# 31  RR-neve_20230305.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506     9
# 32  RR-neve_20230312.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506    10
# 33  RR-neve_20230318.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506    11
# 34  RR-neve_20230328.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506    13
# 35  RR-neve_20230406.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506    14
# 36  RR-neve_20230411.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506    15
# 37  RR-neve_20230414.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506    15
# 38  RR-neve_20230426.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506    17
# 39  RR-neve_20230505.tif  733780.3  (25023, 30022)     [0, 1, 2]     751240506    18

# %%
import os, glob
from rasterio.enums import Resampling
from snow_processing import reproject_resample_visualize, aggregate_weekly

# ── 1. SETTINGS ───────────────────────────────────────────────────────────────
raw_gfsc_root   = r"F:\GeoinformaticsProject\Data\GFSC\GFSC"        
resampled_dir   = r"F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC"
weekly_dir      = r"F:\GeoinformaticsProject\Data\Processed\WEEKLY\GFSC"

dst_crs         = "EPSG:32632"
dst_res         = (20, 20)      # target 20 m

os.makedirs(resampled_dir, exist_ok=True)
os.makedirs(weekly_dir, exist_ok=True)

# ── 2. REPROJECT & RESAMPLE GF + QC ──────────────────────────────────────────
for tile in os.listdir(raw_gfsc_root):
    tile_dir = os.path.join(raw_gfsc_root, tile)
    if not os.path.isdir(tile_dir):
        continue

    # find each GF file + its QC partner
    for gf_fname in glob.glob(os.path.join(tile_dir, "*_GF.tif")):
        qc_fname = gf_fname.replace("_GF.tif", "_QC.tif")
        if not os.path.exists(qc_fname):
            print(f"⚠️  Missing QC for {gf_fname}, skipping QC.")
        
        # output paths
        out_gf = os.path.join(resampled_dir, os.path.basename(gf_fname))
        out_qc = os.path.join(resampled_dir, os.path.basename(qc_fname))

        # GF: continuous → bilinear
        if not os.path.exists(out_gf):
            reproject_resample_visualize(
                src_path         = gf_fname,
                dst_path         = out_gf,
                dst_crs          = dst_crs,
                dst_res          = dst_res,
                resampling_method = Resampling.bilinear,
                visualize        = False
            )

        # QC: categorical → nearest
        if os.path.exists(qc_fname) and not os.path.exists(out_qc):
            reproject_resample_visualize(
                src_path         = qc_fname,
                dst_path         = out_qc,
                dst_crs          = dst_crs,
                dst_res          = dst_res,
                resampling_method = Resampling.nearest,
                visualize        = False
            )

# ── 3. WEEKLY AGGREGATION WITH 20% THRESHOLD ─────────────────────────────────
aggregate_weekly(
    directory    = resampled_dir,
    pattern      = '_GF.tif',    # ← only the fractional-snow layer
    output_dir   = weekly_dir,
    method       = 'max',
    threshold    = 20,
    qc_suffix    = '_QC.tif',
    skip_existing= True,
    summary      = True,
    parallel     = True,
    max_workers  = 6
)
# Out:
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20211107_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20211107_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20211114_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20211114_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20211121_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20211121_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20211128_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20211128_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20211205_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20211205_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20211212_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20211212_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20211219_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20211219_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20211226_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20211226_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20220102_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20220102_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20220109_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20220109_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20220116_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20220116_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20220123_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20220123_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20220130_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20220130_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20220206_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20220206_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20220213_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20220213_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20220220_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20220220_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20220227_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20220227_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20220306_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20220306_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20220313_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20220313_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20220320_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20220320_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20220327_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20220327_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20220403_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20220403_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20220410_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20220410_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20220417_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20220417_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20220424_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20220424_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20221106_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20221106_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20221113_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20221113_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20221120_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20221120_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20221127_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20221127_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20221204_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20221204_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20221211_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20221211_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20221218_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20221218_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20221225_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20221225_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20230101_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20230101_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20230108_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20230108_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20230115_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20230115_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20230122_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20230122_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20230129_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20230129_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20230205_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20230205_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20230212_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20230212_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20230219_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20230219_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20230226_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20230226_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20230305_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20230305_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20230312_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20230312_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20230319_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20230319_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20230326_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20230326_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20230402_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20230402_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20230409_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20230409_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20230416_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20230416_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20230423_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20230423_QC.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20230430_GF.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\GFSC\20230430_QC.tif
# 📦 Aggregating 1 → 2021_W44 (max)
# 📦 Aggregating 1 → 2021_W45 (max)
# 📦 Aggregating 1 → 2021_W46 (max)
# 📦 Aggregating 1 → 2021_W47 (max)📦 Aggregating 1 → 2021_W48 (max)
#
# 📦 Aggregating 1 → 2021_W49 (max)
# 📦 Aggregating 1 → 2021_W50 (max)
# 📦 Aggregating 1 → 2021_W51 (max)
# 📦 Aggregating 1 → 2022_W52 (max)📦 Aggregating 1 → 2022_W01 (max)
#
# 📦 Aggregating 1 → 2022_W02 (max)
# 📦 Aggregating 1 → 2022_W03 (max)
# 📦 Aggregating 1 → 2022_W04 (max)
# 📦 Aggregating 1 → 2022_W05 (max)
# 📦 Aggregating 1 → 2022_W06 (max)
# 📦 Aggregating 1 → 2022_W07 (max)
# 📦 Aggregating 1 → 2022_W08 (max)
# 📦 Aggregating 1 → 2022_W09 (max)
# 📦 Aggregating 1 → 2022_W10 (max)
# 📦 Aggregating 1 → 2022_W11 (max)
# 📦 Aggregating 1 → 2022_W12 (max)
# 📦 Aggregating 1 → 2022_W13 (max)
# 📦 Aggregating 1 → 2022_W14 (max)
# 📦 Aggregating 1 → 2022_W15 (max)
# 📦 Aggregating 1 → 2022_W16 (max)
# 📦 Aggregating 1 → 2022_W44 (max)
# 📦 Aggregating 1 → 2022_W45 (max)
# 📦 Aggregating 1 → 2022_W46 (max)
# 📦 Aggregating 1 → 2022_W47 (max)
# 📦 Aggregating 1 → 2022_W48 (max)
# 📦 Aggregating 1 → 2022_W49 (max)
# 📦 Aggregating 1 → 2022_W50 (max)
# 📦 Aggregating 1 → 2022_W51 (max)
# 📦 Aggregating 1 → 2023_W52 (max)
# 📦 Aggregating 1 → 2023_W01 (max)
# 📦 Aggregating 1 → 2023_W02 (max)
# 📦 Aggregating 1 → 2023_W03 (max)
# 📦 Aggregating 1 → 2023_W04 (max)
# 📦 Aggregating 1 → 2023_W05 (max)📦 Aggregating 1 → 2023_W06 (max)
#
# 📦 Aggregating 1 → 2023_W07 (max)
# 📦 Aggregating 1 → 2023_W08 (max)
# 📦 Aggregating 1 → 2023_W09 (max)
# 📦 Aggregating 1 → 2023_W10 (max)
# 📦 Aggregating 1 → 2023_W11 (max)
# 📦 Aggregating 1 → 2023_W12 (max)
# 📦 Aggregating 1 → 2023_W13 (max)
# 📦 Aggregating 1 → 2023_W14 (max)
# 📦 Aggregating 1 → 2023_W15 (max)
# 📦 Aggregating 1 → 2023_W16 (max)
# 📦 Aggregating 1 → 2023_W17 (max)
# ✔️ Processed: 51, ⏭ Skipped: 0, Outputs: 51
# ['F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2021_W46.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2021_W44.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2021_W49.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2021_W45.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2021_W47.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2021_W48.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2021_W50.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2022_W52.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2022_W01.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2022_W03.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2022_W02.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2021_W51.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2022_W04.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2022_W05.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2022_W09.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2022_W06.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2022_W07.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2022_W08.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2022_W10.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2022_W15.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2022_W13.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2022_W14.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2022_W11.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2022_W12.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2022_W16.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2022_W44.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2022_W46.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2022_W45.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2022_W47.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2022_W48.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2022_W49.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2022_W51.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2023_W01.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2022_W50.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2023_W52.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2023_W02.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2023_W03.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2023_W04.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2023_W07.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2023_W06.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2023_W08.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2023_W05.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2023_W09.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2023_W14.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2023_W10.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2023_W11.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2023_W13.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2023_W12.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2023_W15.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2023_W16.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\GFSC\\2023_W17.tif']

# %%
from snow_processing import split_and_reproject_s2_biweeks
from snow_processing import aggregate_weekly

# === Step 1: Reproject & Resample all S2 ===

split_and_reproject_s2_biweeks(
    input_dir=r"F:\GeoinformaticsProject\Data\S2\S2\SnowMask",
    temp_dir=r"F:\GeoinformaticsProject\Data\Temp\S2-Split",
    output_dir=r"F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S2",
    visualize=False
)
# Out:
# f:\GeoinformaticsProject\Code\snow_processing.py:40: SyntaxWarning: invalid escape sequence '\M'
#   """
# ⏭ Skipping 20220103_20220116_SnowMask_latest — outputs already exist.
# ⏭ Skipping 20220117_20220130_SnowMask_latest — outputs already exist.
# ⏭ Skipping 20220131_20220213_SnowMask_latest — outputs already exist.
# ⏭ Skipping 20220214_20220227_SnowMask_latest — outputs already exist.
# ⏭ Skipping 20220228_20220313_SnowMask_latest — outputs already exist.
# ⏭ Skipping 20220314_20220327_SnowMask_latest — outputs already exist.
# ⏭ Skipping 20220328_20220410_SnowMask_latest — outputs already exist.
# ⏭ Skipping 20220411_20220424_SnowMask_latest — outputs already exist.
# ⏭ Skipping 20221003_20221016_SnowMask_latest — outputs already exist.
# ⏭ Skipping 20221017_20221030_SnowMask_latest — outputs already exist.
# ⏭ Skipping 20221031_20221113_SnowMask_latest — outputs already exist.
# ⏭ Skipping 20221114_20221127_SnowMask_latest — outputs already exist.
# ⏭ Skipping 20221128_20221211_SnowMask_latest — outputs already exist.
# ⏭ Skipping 20221205_20221218_SnowMask_latest — outputs already exist.
# ⏭ Skipping 20221212_20221225_SnowMask_latest — outputs already exist.
# ⏭ Skipping 20221226_20230110_SnowMask_latest — outputs already exist.
# ⏭ Skipping 20230109_20230122_SnowMask_latest — outputs already exist.
# ⏭ Skipping 20230116_20230129_SnowMask_latest — outputs already exist.
# ⏭ Skipping 20230123_20230205_SnowMask_latest — outputs already exist.
# ⏭ Skipping 20230130_20230212_SnowMask_latest — outputs already exist.
# ⏭ Skipping 20230206_20230219_SnowMask_latest — outputs already exist.
# ⏭ Skipping 20230213_20230226_SnowMask_latest — outputs already exist.
# ⏭ Skipping 20230220_20230305_SnowMask_latest — outputs already exist.
# ⏭ Skipping 20230227_20230312_SnowMask_latest — outputs already exist.
# ⏭ Skipping 20230306_20230319_SnowMask_latest — outputs already exist.
# ⏭ Skipping 20230313_20230326_SnowMask_latest — outputs already exist.
# ⏭ Skipping 20230320_20230402_SnowMask_latest — outputs already exist.
# ⏭ Skipping 20230327_20230409_SnowMask_latest — outputs already exist.
# ⏭ Skipping 20230403_20230416_SnowMask_latest — outputs already exist.
# ⏭ Skipping 20230410_20230423_SnowMask_latest — outputs already exist.
# ⏭ Skipping 20230424_20230507_SnowMask_latest — outputs already exist.
# 📦 Aggregating 2 files for 2022_W01 using 'max'
# 📦 Aggregating 2 files for 2022_W03 using 'max'
# 📦 Aggregating 2 files for 2022_W05 using 'max'
# 📦 Aggregating 2 files for 2022_W07 using 'max'
# 📦 Aggregating 2 files for 2022_W09 using 'max'
# 📦 Aggregating 2 files for 2022_W11 using 'max'
# f:\GeoinformaticsProject\Code\snow_processing.py:264: RuntimeWarning: All-NaN slice encountered
#   result = np.nanmax(data_stack, axis=0)
# 📦 Aggregating 2 files for 2022_W13 using 'max'
# 📦 Aggregating 2 files for 2022_W15 using 'max'
# 📦 Aggregating 2 files for 2022_W40 using 'max'📦 Aggregating 2 files for 2022_W42 using 'max'
#
# 📦 Aggregating 2 files for 2022_W44 using 'max'
# 📦 Aggregating 2 files for 2022_W46 using 'max'
# 📦 Aggregating 2 files for 2022_W48 using 'max'
# 📦 Aggregating 2 files for 2022_W49 using 'max'
# 📦 Aggregating 2 files for 2022_W50 using 'max'
# 📦 Aggregating 2 files for 2022_W52 using 'max'
# 📦 Aggregating 2 files for 2023_W02 using 'max'
# 📦 Aggregating 2 files for 2023_W03 using 'max'
# 📦 Aggregating 2 files for 2023_W04 using 'max'
# 📦 Aggregating 2 files for 2023_W05 using 'max'
# 📦 Aggregating 2 files for 2023_W06 using 'max'📦 Aggregating 2 files for 2023_W07 using 'max'
#
# 📦 Aggregating 2 files for 2023_W08 using 'max'
# 📦 Aggregating 2 files for 2023_W09 using 'max'
# 📦 Aggregating 2 files for 2023_W10 using 'max'
# 📦 Aggregating 2 files for 2023_W11 using 'max'
# 📦 Aggregating 2 files for 2023_W12 using 'max'
# 📦 Aggregating 2 files for 2023_W13 using 'max'
# 📦 Aggregating 2 files for 2023_W14 using 'max'
# 📦 Aggregating 2 files for 2023_W15 using 'max'
# 📦 Aggregating 2 files for 2023_W17 using 'max'
#
# 📊 Summary:
#   ✔️ Processed: 31
#   ⏭ Skipped: 0
#   📁 Outputs: 31
# ['F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S2\\2022_W11.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S2\\2022_W01.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S2\\2022_W05.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S2\\2022_W07.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S2\\2022_W09.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S2\\2022_W03.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S2\\2022_W13.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S2\\2022_W46.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S2\\2022_W48.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S2\\2022_W49.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S2\\2022_W50.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S2\\2022_W52.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S2\\2023_W02.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S2\\2022_W15.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S2\\2022_W40.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S2\\2022_W44.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S2\\2022_W42.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S2\\2023_W03.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S2\\2023_W08.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S2\\2023_W04.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S2\\2023_W07.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S2\\2023_W09.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S2\\2023_W05.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S2\\2023_W11.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S2\\2023_W12.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S2\\2023_W14.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S2\\2023_W13.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S2\\2023_W06.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S2\\2023_W15.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S2\\2023_W10.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S2\\2023_W17.tif']

# %%
from snow_processing import check_all_products_side_by_side
import pandas as pd

# Define your raw input folders
product_folders = [
    ("MODIS", r"F:\GeoinformaticsProject\Data\MODIS_SnowMask\2022", False),
    ("MODIS", r"F:\GeoinformaticsProject\Data\MODIS_SnowMask\2023", False),
    ("GFSC",  r"F:\GeoinformaticsProject\Data\GFSC\GFSC", True),
    ("S2", r"F:\GeoinformaticsProject\Data\Processed\WEEKLY\S2", False),
    ("S3",    r"F:\GeoinformaticsProject\Data\S3\S3\SnowMask", False),
]

# Run the check
df = check_all_products_side_by_side(product_folders, start_year=2022, end_year=2023)

# Show all weeks
pd.set_option("display.max_rows", None)
display(df)
# Out:
# f:\GeoinformaticsProject\Code\snow_processing.py:47: SyntaxWarning: invalid escape sequence '\M'
#   """
# 🔍 Scanning MODIS → F:\GeoinformaticsProject\Data\MODIS_SnowMask\2022
#    ➤ Found 15 unique weeks
# 🔍 Scanning MODIS → F:\GeoinformaticsProject\Data\MODIS_SnowMask\2023
#    ➤ Found 18 unique weeks
# 🔍 Scanning GFSC → F:\GeoinformaticsProject\Data\GFSC\GFSC
#    ➤ Found 51 unique weeks
# 🔍 Scanning S2 → F:\GeoinformaticsProject\Data\Processed\WEEKLY\S2
#    ➤ Found 31 unique weeks
# 🔍 Scanning S3 → F:\GeoinformaticsProject\Data\S3\S3\SnowMask
#    ➤ Found 40 unique weeks
#          Week MODIS GFSC S2 S3 Common_Week
# 0    2022_W01     ❌    ✅  ✅  ✅
# 1    2022_W02     ✅    ✅  ❌  ✅
# 2    2022_W03     ❌    ✅  ✅  ✅
# 3    2022_W04     ✅    ✅  ❌  ✅
# 4    2022_W05     ❌    ✅  ✅  ✅
# 5    2022_W06     ✅    ✅  ❌  ✅
# 6    2022_W07     ✅    ✅  ✅  ✅           ✅
# 7    2022_W08     ✅    ✅  ❌  ✅
# 8    2022_W09     ✅    ✅  ✅  ✅           ✅
# 9    2022_W10     ✅    ✅  ❌  ✅
# 10   2022_W11     ✅    ✅  ✅  ✅           ✅
# 11   2022_W12     ✅    ✅  ❌  ✅
# 12   2022_W13     ❌    ✅  ✅  ❌
# 13   2022_W14     ✅    ✅  ❌  ❌
# 14   2022_W15     ❌    ✅  ✅  ❌
# 15   2022_W16     ✅    ✅  ❌  ❌
# 16   2022_W17     ✅    ❌  ❌  ❌
# 17   2022_W18     ❌    ❌  ❌  ❌
# 18   2022_W19     ✅    ❌  ❌  ❌
# 19   2022_W20     ❌    ❌  ❌  ❌
# 20   2022_W21     ❌    ❌  ❌  ❌
# 21   2022_W22     ❌    ❌  ❌  ❌
# 22   2022_W23     ❌    ❌  ❌  ❌
# 23   2022_W24     ❌    ❌  ❌  ❌
# 24   2022_W25     ❌    ❌  ❌  ❌
# 25   2022_W26     ❌    ❌  ❌  ❌
# 26   2022_W27     ❌    ❌  ❌  ❌
# 27   2022_W28     ❌    ❌  ❌  ❌
# 28   2022_W29     ❌    ❌  ❌  ❌
# 29   2022_W30     ❌    ❌  ❌  ❌
# 30   2022_W31     ❌    ❌  ❌  ❌
# 31   2022_W32     ❌    ❌  ❌  ❌
# 32   2022_W33     ❌    ❌  ❌  ❌
# 33   2022_W34     ❌    ❌  ❌  ❌
# 34   2022_W35     ❌    ❌  ❌  ❌
# 35   2022_W36     ❌    ❌  ❌  ❌
# 36   2022_W37     ❌    ❌  ❌  ❌
# 37   2022_W38     ❌    ❌  ❌  ❌
# 38   2022_W39     ❌    ❌  ❌  ❌
# 39   2022_W40     ❌    ❌  ✅  ✅
# 40   2022_W41     ❌    ❌  ❌  ✅
# 41   2022_W42     ❌    ❌  ✅  ✅
# 42   2022_W43     ✅    ❌  ❌  ✅
# 43   2022_W44     ✅    ✅  ✅  ✅           ✅
# 44   2022_W45     ❌    ✅  ❌  ✅
# 45   2022_W46     ❌    ✅  ✅  ✅
# 46   2022_W47     ✅    ✅  ❌  ✅
# 47   2022_W48     ❌    ✅  ✅  ✅
# 48   2022_W49     ✅    ✅  ✅  ✅           ✅
# 49   2022_W50     ✅    ✅  ✅  ✅           ✅
# 50   2022_W51     ❌    ✅  ❌  ✅
# 51   2022_W52     ✅    ✅  ✅  ❌
# 52   2022_W53     ❌    ❌  ❌  ❌
# 53   2023_W01     ❌    ✅  ❌  ❌
# 54   2023_W02     ✅    ✅  ✅  ❌
# 55   2023_W03     ❌    ✅  ✅  ✅
# 56   2023_W04     ✅    ✅  ✅  ✅           ✅
# 57   2023_W05     ❌    ✅  ✅  ✅
# 58   2023_W06     ✅    ✅  ✅  ✅           ✅
# 59   2023_W07     ❌    ✅  ✅  ✅
# 60   2023_W08     ✅    ✅  ✅  ✅           ✅
# 61   2023_W09     ✅    ✅  ✅  ✅           ✅
# 62   2023_W10     ✅    ✅  ✅  ✅           ✅
# 63   2023_W11     ✅    ✅  ✅  ✅           ✅
# 64   2023_W12     ❌    ✅  ✅  ✅
# 65   2023_W13     ✅    ✅  ✅  ✅           ✅
# 66   2023_W14     ✅    ✅  ✅  ✅           ✅
# 67   2023_W15     ✅    ✅  ✅  ✅           ✅
# 68   2023_W16     ❌    ✅  ❌  ✅
# 69   2023_W17     ✅    ✅  ✅  ✅           ✅
# 70   2023_W18     ✅    ❌  ❌  ✅
# 71   2023_W19     ❌    ❌  ❌  ❌
# 72   2023_W20     ❌    ❌  ❌  ❌
# 73   2023_W21     ❌    ❌  ❌  ❌
# 74   2023_W22     ❌    ❌  ❌  ❌
# 75   2023_W23     ❌    ❌  ❌  ❌
# 76   2023_W24     ❌    ❌  ❌  ❌
# 77   2023_W25     ❌    ❌  ❌  ❌
# 78   2023_W26     ❌    ❌  ❌  ❌
# 79   2023_W27     ❌    ❌  ❌  ❌
# 80   2023_W28     ❌    ❌  ❌  ❌
# 81   2023_W29     ❌    ❌  ❌  ❌
# 82   2023_W30     ❌    ❌  ❌  ❌
# 83   2023_W31     ❌    ❌  ❌  ❌
# 84   2023_W32     ❌    ❌  ❌  ❌
# 85   2023_W33     ❌    ❌  ❌  ❌
# 86   2023_W34     ❌    ❌  ❌  ❌
# 87   2023_W35     ❌    ❌  ❌  ❌
# 88   2023_W36     ❌    ❌  ❌  ❌
# 89   2023_W37     ❌    ❌  ❌  ❌
# 90   2023_W38     ❌    ❌  ❌  ❌
# 91   2023_W39     ❌    ❌  ❌  ❌
# 92   2023_W40     ❌    ❌  ❌  ❌
# 93   2023_W41     ❌    ❌  ❌  ❌
# 94   2023_W42     ❌    ❌  ❌  ❌
# 95   2023_W43     ❌    ❌  ❌  ❌
# 96   2023_W44     ❌    ❌  ❌  ❌
# 97   2023_W45     ❌    ❌  ❌  ❌
# 98   2023_W46     ❌    ❌  ❌  ❌
# 99   2023_W47     ❌    ❌  ❌  ❌
# 100  2023_W48     ❌    ❌  ❌  ❌
# 101  2023_W49     ❌    ❌  ❌  ❌
# 102  2023_W50     ❌    ❌  ❌  ❌
# 103  2023_W51     ❌    ❌  ❌  ❌
# 104  2023_W52     ❌    ❌  ❌  ❌
# 105  2023_W53     ❌    ❌  ❌  ❌

# %%
import os
import sys
from rasterio.enums import Resampling
from snow_processing import reproject_resample_visualize

# === Paths ===
input_dir = r"F:\GeoinformaticsProject\Data\S3\S3\SnowMask"
resampled_dir = r"F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3"
weekly_dir = r"F:\GeoinformaticsProject\Data\Processed\WEEKLY\S3"

# === Step 1: Resample & Reproject all S3 masks ===
input_files = [f for f in os.listdir(input_dir) if f.endswith('.tif') and '_datemap' not in f]

for fname in input_files:
    src_path = os.path.join(input_dir, fname)
    dst_path = os.path.join(resampled_dir, f"RR-{fname}")
    
    reproject_resample_visualize(
        src_path=src_path,
        dst_path=dst_path,
        dst_crs="EPSG:32632",
        dst_res=(300, 300),
        resampling_method=Resampling.nearest,
        visualize=False
    )
# Out:
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3\RR-20220103_20220109_SnowMask(0.42)_latest.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3\RR-20220110_20220116_SnowMask(0.42)_latest.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3\RR-20220117_20220123_SnowMask(0.42)_latest.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3\RR-20220124_20220130_SnowMask(0.42)_latest.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3\RR-20220131_20220206_SnowMask(0.42)_latest.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3\RR-20220207_20220213_SnowMask(0.42)_latest.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3\RR-20220214_20220220_SnowMask(0.42)_latest.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3\RR-20220221_20220227_SnowMask(0.42)_latest.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3\RR-20220228_20220306_SnowMask(0.42)_latest.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3\RR-20220307_20220313_SnowMask(0.42)_latest.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3\RR-20220314_20220320_SnowMask(0.42)_latest.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3\RR-20220321_20220327_SnowMask(0.42)_latest.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3\RR-20221003_20221009_SnowMask(0.42)_latest.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3\RR-20221010_20221016_SnowMask(0.42)_latest.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3\RR-20221017_20221023_SnowMask(0.42)_latest.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3\RR-20221024_20221030_SnowMask(0.42)_latest.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3\RR-20221031_20221106_SnowMask(0.42)_latest.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3\RR-20221107_20221113_SnowMask(0.42)_latest.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3\RR-20221114_20221120_SnowMask(0.42)_latest.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3\RR-20221121_20221127_SnowMask(0.42)_latest.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3\RR-20221128_20221204_SnowMask(0.42)_latest.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3\RR-20221205_20221211_SnowMask(0.42)_latest.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3\RR-20221212_20221218_SnowMask(0.42)_latest.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3\RR-20230116_20230122_SnowMask(0.42)_latest.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3\RR-20230123_20230129_SnowMask(0.42)_latest.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3\RR-20230130_20230205_SnowMask(0.42)_latest.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3\RR-20230206_20230212_SnowMask(0.42)_latest.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3\RR-20230213_20230219_SnowMask(0.42)_latest.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3\RR-20230220_20230226_SnowMask(0.42)_latest.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3\RR-20230227_20230305_SnowMask(0.42)_latest.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3\RR-20230306_20230312_SnowMask(0.42)_latest.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3\RR-20230313_20230319_SnowMask(0.42)_latest.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3\RR-20230320_20230326_SnowMask(0.42)_latest.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3\RR-20230327_20230402_SnowMask(0.42)_latest.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3\RR-20230403_20230409_SnowMask(0.42)_latest.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3\RR-20230410_20230416_SnowMask(0.42)_latest.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3\RR-20230417_20230423_SnowMask(0.42)_latest.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3\RR-20230424_20230430_SnowMask(0.42)_latest.tif
# ✅ Resampled and reprojected saved to: F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3\RR-20230501_20230507_SnowMask(0.42)_latest.tif
# 📦 Aggregating 1 files for 2022_W01 using 'max'
# 📦 Aggregating 1 files for 2022_W02 using 'max'
# 📦 Aggregating 1 files for 2022_W03 using 'max'
# 📦 Aggregating 1 files for 2022_W04 using 'max'
# 📦 Aggregating 1 files for 2022_W05 using 'max'
# 📦 Aggregating 1 files for 2022_W06 using 'max'
# f:\GeoinformaticsProject\Code\snow_processing.py:271: RuntimeWarning: All-NaN slice encountered
#   result = np.nanmax(data_stack, axis=0)
# 📦 Aggregating 1 files for 2022_W07 using 'max'📦 Aggregating 1 files for 2022_W08 using 'max'
#
# 📦 Aggregating 1 files for 2022_W10 using 'max'
# 📦 Aggregating 1 files for 2022_W09 using 'max'
# 📦 Aggregating 1 files for 2022_W11 using 'max'
# 📦 Aggregating 1 files for 2022_W12 using 'max'
# 📦 Aggregating 1 files for 2022_W40 using 'max'
# 📦 Aggregating 1 files for 2022_W41 using 'max'
# 📦 Aggregating 1 files for 2022_W43 using 'max'
# 📦 Aggregating 1 files for 2022_W42 using 'max'
# 📦 Aggregating 1 files for 2022_W44 using 'max'
# 📦 Aggregating 1 files for 2022_W45 using 'max'
# 📦 Aggregating 1 files for 2022_W46 using 'max'📦 Aggregating 1 files for 2022_W47 using 'max'
#
# 📦 Aggregating 1 files for 2022_W48 using 'max'
# 📦 Aggregating 1 files for 2022_W49 using 'max'
# 📦 Aggregating 1 files for 2022_W50 using 'max'
# 📦 Aggregating 1 files for 2023_W03 using 'max'
# 📦 Aggregating 1 files for 2023_W04 using 'max'
# 📦 Aggregating 1 files for 2023_W05 using 'max'
# 📦 Aggregating 1 files for 2023_W06 using 'max'
# 📦 Aggregating 1 files for 2023_W07 using 'max'
# 📦 Aggregating 1 files for 2023_W08 using 'max'
# 📦 Aggregating 1 files for 2023_W09 using 'max'
# 📦 Aggregating 1 files for 2023_W10 using 'max'📦 Aggregating 1 files for 2023_W11 using 'max'
#
# 📦 Aggregating 1 files for 2023_W12 using 'max'
# 📦 Aggregating 1 files for 2023_W14 using 'max'
# 📦 Aggregating 1 files for 2023_W13 using 'max'
# 📦 Aggregating 1 files for 2023_W15 using 'max'
# 📦 Aggregating 1 files for 2023_W16 using 'max'
# 📦 Aggregating 1 files for 2023_W18 using 'max'
# 📦 Aggregating 1 files for 2023_W17 using 'max'
#
# 📊 Summary:
#   ✔️ Processed: 39
#   ⏭ Skipped: 0
#   📁 Outputs: 39

# %%
from snow_processing import aggregate_weekly

# — S2 weekly (no extra threshold) —
aggregate_weekly(
    directory     = r"F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S2",
    pattern       = '.tif',       # picks up your binary S2 masks
    output_dir    = r"F:\GeoinformaticsProject\Data\Processed\WEEKLY\S2",
    method        = 'max',        # 1 if any day in the week was snow
    threshold     = None,         # keep the raw 0/1 values
    qc_suffix     = '_QC.tif',    # if you have QC files, else this does nothing
    skip_existing = False,
    summary       = True,
    parallel      = True,
    max_workers   = 4
)

# — S3 weekly (same) —
aggregate_weekly(
    directory     = r"F:\GeoinformaticsProject\Data\Processed\RESAMPLED-REPROJECTED\S3",
    pattern       = '.tif',
    output_dir    = r"F:\GeoinformaticsProject\Data\Processed\WEEKLY\S3",
    method        = 'max',
    threshold     = None,
    qc_suffix     = '_QC.tif',
    skip_existing = False,
    summary       = True,
    parallel      = True,
    max_workers   = 4
)
# Out:
# 📦 Aggregating 2 → 2022_W01 (max)
# 📦 Aggregating 2 → 2022_W03 (max)
# 📦 Aggregating 2 → 2022_W05 (max)
# 📦 Aggregating 2 → 2022_W07 (max)
# f:\GeoinformaticsProject\Code\snow_processing.py:282: RuntimeWarning: All-NaN slice encountered
#   result = np.nanmax(arr, axis=0)
# 📦 Aggregating 2 → 2022_W09 (max)
# 📦 Aggregating 2 → 2022_W11 (max)
# 📦 Aggregating 2 → 2022_W13 (max)
# 📦 Aggregating 2 → 2022_W15 (max)
# 📦 Aggregating 2 → 2022_W40 (max)
# 📦 Aggregating 2 → 2022_W42 (max)
# 📦 Aggregating 2 → 2022_W44 (max)
# 📦 Aggregating 2 → 2022_W46 (max)
# 📦 Aggregating 2 → 2022_W48 (max)
# 📦 Aggregating 2 → 2022_W49 (max)
# 📦 Aggregating 2 → 2022_W50 (max)
# 📦 Aggregating 2 → 2022_W52 (max)
# 📦 Aggregating 2 → 2023_W02 (max)
# 📦 Aggregating 2 → 2023_W03 (max)
# 📦 Aggregating 2 → 2023_W04 (max)
# 📦 Aggregating 2 → 2023_W05 (max)
# 📦 Aggregating 2 → 2023_W06 (max)
# 📦 Aggregating 2 → 2023_W07 (max)
# 📦 Aggregating 2 → 2023_W08 (max)
# 📦 Aggregating 2 → 2023_W09 (max)
# 📦 Aggregating 2 → 2023_W10 (max)
# 📦 Aggregating 2 → 2023_W11 (max)
# 📦 Aggregating 2 → 2023_W12 (max)
# 📦 Aggregating 2 → 2023_W13 (max)
# 📦 Aggregating 2 → 2023_W14 (max)
# 📦 Aggregating 2 → 2023_W15 (max)
# 📦 Aggregating 2 → 2023_W17 (max)
# ✔️ Processed: 31, ⏭ Skipped: 0, Outputs: 31
# 📦 Aggregating 1 → 2022_W01 (max)
# 📦 Aggregating 1 → 2022_W02 (max)
# 📦 Aggregating 1 → 2022_W03 (max)
# 📦 Aggregating 1 → 2022_W04 (max)
# 📦 Aggregating 1 → 2022_W05 (max)
# 📦 Aggregating 1 → 2022_W06 (max)📦 Aggregating 1 → 2022_W07 (max)
#
# 📦 Aggregating 1 → 2022_W08 (max)
# 📦 Aggregating 1 → 2022_W09 (max)📦 Aggregating 1 → 2022_W10 (max)
#
# 📦 Aggregating 1 → 2022_W11 (max)
# 📦 Aggregating 1 → 2022_W12 (max)
# 📦 Aggregating 1 → 2022_W40 (max)
# 📦 Aggregating 1 → 2022_W41 (max)
# 📦 Aggregating 1 → 2022_W42 (max)
# 📦 Aggregating 1 → 2022_W43 (max)
# 📦 Aggregating 1 → 2022_W44 (max)
# 📦 Aggregating 1 → 2022_W45 (max)
# 📦 Aggregating 1 → 2022_W46 (max)
# 📦 Aggregating 1 → 2022_W47 (max)
# 📦 Aggregating 1 → 2022_W48 (max)
# 📦 Aggregating 1 → 2022_W49 (max)
# 📦 Aggregating 1 → 2022_W50 (max)
# 📦 Aggregating 1 → 2023_W03 (max)
# 📦 Aggregating 1 → 2023_W04 (max)
# 📦 Aggregating 1 → 2023_W05 (max)
# 📦 Aggregating 1 → 2023_W06 (max)
# 📦 Aggregating 1 → 2023_W07 (max)
# 📦 Aggregating 1 → 2023_W08 (max)
# 📦 Aggregating 1 → 2023_W09 (max)📦 Aggregating 1 → 2023_W10 (max)
# 📦 Aggregating 1 → 2023_W11 (max)
# 📦 Aggregating 1 → 2023_W12 (max)
#
# 📦 Aggregating 1 → 2023_W13 (max)
# 📦 Aggregating 1 → 2023_W14 (max)
# 📦 Aggregating 1 → 2023_W15 (max)
# 📦 Aggregating 1 → 2023_W16 (max)
# 📦 Aggregating 1 → 2023_W17 (max)📦 Aggregating 1 → 2023_W18 (max)
#
# ✔️ Processed: 39, ⏭ Skipped: 0, Outputs: 39
# ['F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S3\\2022_W04.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S3\\2022_W02.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S3\\2022_W01.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S3\\2022_W03.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S3\\2022_W05.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S3\\2022_W06.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S3\\2022_W07.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S3\\2022_W10.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S3\\2022_W09.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S3\\2022_W08.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S3\\2022_W12.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S3\\2022_W11.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S3\\2022_W41.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S3\\2022_W40.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S3\\2022_W42.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S3\\2022_W43.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S3\\2022_W44.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S3\\2022_W46.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S3\\2022_W45.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S3\\2022_W47.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S3\\2022_W50.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S3\\2022_W48.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S3\\2023_W04.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S3\\2022_W49.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S3\\2023_W03.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S3\\2023_W05.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S3\\2023_W06.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S3\\2023_W07.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S3\\2023_W08.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S3\\2023_W12.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S3\\2023_W09.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S3\\2023_W11.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S3\\2023_W10.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S3\\2023_W13.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S3\\2023_W14.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S3\\2023_W15.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S3\\2023_W16.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S3\\2023_W17.tif',
#  'F:\\GeoinformaticsProject\\Data\\Processed\\WEEKLY\\S3\\2023_W18.tif']

# %%
import os
from snow_processing import match_raster_grid
from rasterio.enums import Resampling

# ── 1. Define only the weeks you actually want to align ────────────────────
common_weeks = [
    '2022_W07', '2022_W09', '2022_W11',
    '2022_W44', '2022_W49', '2022_W50',
    '2023_W04', '2023_W06', '2023_W08',
    '2023_W09', '2023_W10', '2023_W11',
    '2023_W13', '2023_W14', '2023_W15', '2023_W17'
]

# ── 2. Paths ───────────────────────────────────────────────────────────────
weekly_modis_ref = r"F:/GeoinformaticsProject/Data/Processed/WEEKLY/MODIS"
aligned_base     = r"E:\ALIGNED\ToMODIS"
os.makedirs(aligned_base, exist_ok=True)

# ── 3. Align only those weeks for GFSC, S2 and S3 ─────────────────────────
for product in ["GFSC", "S2", "S3"]:
    src_folder = rf"F:/GeoinformaticsProject/Data/Processed/WEEKLY/{product}"
    dst_folder = os.path.join(aligned_base, product)
    os.makedirs(dst_folder, exist_ok=True)

    for week in common_weeks:
        src_path = os.path.join(src_folder, f"{week}.tif")
        ref_path = os.path.join(weekly_modis_ref, f"{week}.tif")
        out_path = os.path.join(dst_folder,   f"{week}.tif")

        # skip if either input is missing or output already exists
        if not os.path.exists(src_path) or not os.path.exists(ref_path) or os.path.exists(out_path):
            continue

        match_raster_grid(
            reference_path   = ref_path,
            target_path      = src_path,
            output_path      = out_path,
            resampling_method= Resampling.nearest
        )
        print(f"Aligned {product} {week} → {out_path}")
# Out:
# ✅ Reprojected to match: E:\ALIGNED\ToMODIS\GFSC\2022_W07.tif
# Aligned GFSC 2022_W07 → E:\ALIGNED\ToMODIS\GFSC\2022_W07.tif
# ✅ Reprojected to match: E:\ALIGNED\ToMODIS\GFSC\2022_W09.tif
# Aligned GFSC 2022_W09 → E:\ALIGNED\ToMODIS\GFSC\2022_W09.tif
# ✅ Reprojected to match: E:\ALIGNED\ToMODIS\GFSC\2022_W11.tif
# Aligned GFSC 2022_W11 → E:\ALIGNED\ToMODIS\GFSC\2022_W11.tif
# ✅ Reprojected to match: E:\ALIGNED\ToMODIS\GFSC\2022_W44.tif
# Aligned GFSC 2022_W44 → E:\ALIGNED\ToMODIS\GFSC\2022_W44.tif
# ✅ Reprojected to match: E:\ALIGNED\ToMODIS\GFSC\2022_W49.tif
# Aligned GFSC 2022_W49 → E:\ALIGNED\ToMODIS\GFSC\2022_W49.tif
# ✅ Reprojected to match: E:\ALIGNED\ToMODIS\GFSC\2022_W50.tif
# Aligned GFSC 2022_W50 → E:\ALIGNED\ToMODIS\GFSC\2022_W50.tif
# ✅ Reprojected to match: E:\ALIGNED\ToMODIS\GFSC\2023_W04.tif
# Aligned GFSC 2023_W04 → E:\ALIGNED\ToMODIS\GFSC\2023_W04.tif
# ✅ Reprojected to match: E:\ALIGNED\ToMODIS\GFSC\2023_W06.tif
# Aligned GFSC 2023_W06 → E:\ALIGNED\ToMODIS\GFSC\2023_W06.tif
# ✅ Reprojected to match: E:\ALIGNED\ToMODIS\GFSC\2023_W08.tif
# Aligned GFSC 2023_W08 → E:\ALIGNED\ToMODIS\GFSC\2023_W08.tif
# ✅ Reprojected to match: E:\ALIGNED\ToMODIS\GFSC\2023_W09.tif
# Aligned GFSC 2023_W09 → E:\ALIGNED\ToMODIS\GFSC\2023_W09.tif
# ✅ Reprojected to match: E:\ALIGNED\ToMODIS\GFSC\2023_W10.tif
# Aligned GFSC 2023_W10 → E:\ALIGNED\ToMODIS\GFSC\2023_W10.tif
# ✅ Reprojected to match: E:\ALIGNED\ToMODIS\GFSC\2023_W11.tif
# Aligned GFSC 2023_W11 → E:\ALIGNED\ToMODIS\GFSC\2023_W11.tif
# ✅ Reprojected to match: E:\ALIGNED\ToMODIS\GFSC\2023_W13.tif
# Aligned GFSC 2023_W13 → E:\ALIGNED\ToMODIS\GFSC\2023_W13.tif
# ✅ Reprojected to match: E:\ALIGNED\ToMODIS\GFSC\2023_W14.tif
# Aligned GFSC 2023_W14 → E:\ALIGNED\ToMODIS\GFSC\2023_W14.tif
# ✅ Reprojected to match: E:\ALIGNED\ToMODIS\GFSC\2023_W15.tif
# Aligned GFSC 2023_W15 → E:\ALIGNED\ToMODIS\GFSC\2023_W15.tif
# ✅ Reprojected to match: E:\ALIGNED\ToMODIS\GFSC\2023_W17.tif
# Aligned GFSC 2023_W17 → E:\ALIGNED\ToMODIS\GFSC\2023_W17.tif
# ✅ Reprojected to match: E:\ALIGNED\ToMODIS\S2\2022_W07.tif
# Aligned S2 2022_W07 → E:\ALIGNED\ToMODIS\S2\2022_W07.tif
# ✅ Reprojected to match: E:\ALIGNED\ToMODIS\S2\2022_W09.tif
# Aligned S2 2022_W09 → E:\ALIGNED\ToMODIS\S2\2022_W09.tif
# ✅ Reprojected to match: E:\ALIGNED\ToMODIS\S2\2022_W11.tif
# Aligned S2 2022_W11 → E:\ALIGNED\ToMODIS\S2\2022_W11.tif
# ✅ Reprojected to match: E:\ALIGNED\ToMODIS\S2\2022_W44.tif
# Aligned S2 2022_W44 → E:\ALIGNED\ToMODIS\S2\2022_W44.tif
# ✅ Reprojected to match: E:\ALIGNED\ToMODIS\S2\2022_W49.tif
# Aligned S2 2022_W49 → E:\ALIGNED\ToMODIS\S2\2022_W49.tif
# ✅ Reprojected to match: E:\ALIGNED\ToMODIS\S2\2022_W50.tif
# Aligned S2 2022_W50 → E:\ALIGNED\ToMODIS\S2\2022_W50.tif
# ✅ Reprojected to match: E:\ALIGNED\ToMODIS\S2\2023_W04.tif
# Aligned S2 2023_W04 → E:\ALIGNED\ToMODIS\S2\2023_W04.tif
# ✅ Reprojected to match: E:\ALIGNED\ToMODIS\S2\2023_W06.tif
# Aligned S2 2023_W06 → E:\ALIGNED\ToMODIS\S2\2023_W06.tif
# ✅ Reprojected to match: E:\ALIGNED\ToMODIS\S2\2023_W08.tif
# Aligned S2 2023_W08 → E:\ALIGNED\ToMODIS\S2\2023_W08.tif
# ✅ Reprojected to match: E:\ALIGNED\ToMODIS\S2\2023_W09.tif
# Aligned S2 2023_W09 → E:\ALIGNED\ToMODIS\S2\2023_W09.tif
# ✅ Reprojected to match: E:\ALIGNED\ToMODIS\S2\2023_W10.tif
# Aligned S2 2023_W10 → E:\ALIGNED\ToMODIS\S2\2023_W10.tif
# ✅ Reprojected to match: E:\ALIGNED\ToMODIS\S2\2023_W11.tif
# Aligned S2 2023_W11 → E:\ALIGNED\ToMODIS\S2\2023_W11.tif
# ✅ Reprojected to match: E:\ALIGNED\ToMODIS\S2\2023_W13.tif
# Aligned S2 2023_W13 → E:\ALIGNED\ToMODIS\S2\2023_W13.tif
# ✅ Reprojected to match: E:\ALIGNED\ToMODIS\S2\2023_W14.tif
# Aligned S2 2023_W14 → E:\ALIGNED\ToMODIS\S2\2023_W14.tif
# ✅ Reprojected to match: E:\ALIGNED\ToMODIS\S2\2023_W15.tif
# Aligned S2 2023_W15 → E:\ALIGNED\ToMODIS\S2\2023_W15.tif
# ✅ Reprojected to match: E:\ALIGNED\ToMODIS\S2\2023_W17.tif
# Aligned S2 2023_W17 → E:\ALIGNED\ToMODIS\S2\2023_W17.tif
# ✅ Reprojected to match: E:\ALIGNED\ToMODIS\S3\2022_W07.tif
# Aligned S3 2022_W07 → E:\ALIGNED\ToMODIS\S3\2022_W07.tif
# ✅ Reprojected to match: E:\ALIGNED\ToMODIS\S3\2022_W09.tif
# Aligned S3 2022_W09 → E:\ALIGNED\ToMODIS\S3\2022_W09.tif
# ---------------------------------------------------------------------------
# CPLE_FileIOError                          Traceback (most recent call last)
# File rasterio\\_io.pyx:1530, in rasterio._io.DatasetWriterBase.__init__()
#
# File rasterio\\_err.pyx:359, in rasterio._err.exc_wrap_pointer()
#
# CPLE_FileIOError: 2022_W11.tif: Free disk space available is 2128728064 bytes, whereas 3004962024 are at least necessary. You can disable this check by defining the CHECK_DISK_FREE_SPACE configuration option to FALSE.
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# Cell In[5], line 34
#      31 if not os.path.exists(src_path) or not os.path.exists(ref_path) or os.path.exists(out_path):
#      32     continue
# ---> 34 match_raster_grid(
#      35     reference_path   = ref_path,
#      36     target_path      = src_path,
#      37     output_path      = out_path,
#      38     resampling_method= Resampling.nearest
#      39 )
#      40 print(f"Aligned {product} {week} → {out_path}")
#
# File f:\GeoinformaticsProject\Code\snow_processing.py:492, in match_raster_grid(reference_path, target_path, output_path, resampling_method)
#     484 # Save to file
#     485 dst_profile.update({
#     486     'height': dst_shape[0],
#     487     'width': dst_shape[1],
#     488     'transform': dst_transform,
#     489     'crs': dst_crs
#     490 })
# --> 492 with rasterio.open(output_path, 'w', **dst_profile) as dst:
#     493     dst.write(dst_array, 1)
#     495 print(f"✅ Reprojected to match: {output_path}")
#
# File c:\Users\Lenovo\anaconda3\envs\geop_env\Lib\site-packages\rasterio\env.py:463, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwds)
#     460     session = DummySession()
#     462 with env_ctor(session=session):
# --> 463     return f(*args, **kwds)
#
# File c:\Users\Lenovo\anaconda3\envs\geop_env\Lib\site-packages\rasterio\__init__.py:365, in open(fp, mode, driver, width, height, count, crs, transform, dtype, nodata, sharing, opener, **kwargs)
#     363 writer = get_writer_for_driver(driver)
#     364 if writer is not None:
# --> 365     dataset = writer(
#     366         path,
#     367         mode,
#     368         driver=driver,
#     369         width=width,
#     370         height=height,
#     371         count=count,
#     372         crs=crs,
#     373         transform=transform,
#     374         dtype=dtype,
#     375         nodata=nodata,
#     376         sharing=sharing,
#     377         **kwargs
#     378     )
#     379 else:
#     380     raise DriverCapabilityError(
#     381         "Writer does not exist for driver: %s" % str(driver)
#     382     )
#
# File rasterio\\_io.pyx:1542, in rasterio._io.DatasetWriterBase.__init__()
#
# RasterioIOError: 2022_W11.tif: Free disk space available is 2128728064 bytes, whereas 3004962024 are at least necessary. You can disable this check by defining the CHECK_DISK_FREE_SPACE configuration option to FALSE.

# %%
from snow_processing import visual_compare_rasters

week = "2022_W11"

visual_compare_rasters(
    raster_path1=r"F:\GeoinformaticsProject\Data\Processed\WEEKLY\MODIS\2022_W11.tif",
    raster_path2=r"E:\ALIGNED\ToMODIS\GFSC\2022_W11.tif",
    labels=(f"MODIS {week}", f"GFSC {week}"),
    difference=True,
    downsample=5
)

# %%
from snow_processing import visual_compare_rasters_strict

week = "2022_W11"
visual_compare_rasters_strict(
    raster_path1=r"F:\GeoinformaticsProject\Data\Processed\WEEKLY\MODIS\2022_W11.tif",
    raster_path2=r"E:\ALIGNED\ToMODIS\GFSC\2022_W11.tif",
    labels       = (f"MODIS {week}", f"GFSC {week}"),
    difference   = True,
    downsample   = 5
)

# %%
from snow_processing import visual_compare_rasters_strict

week = "2022_W11"
visual_compare_rasters_strict(
    raster_path1=r"E:\ALIGNED\ToMODIS\GFSC\2022_W11.tif",
    raster_path2=r"E:\ALIGNED\ToMODIS\S2\2022_W11.tif",
    labels       = (f"GFSC {week}", f"S2 {week}"),
    difference   = True,
    downsample   = 1
)

# %%
from snow_processing import visual_compare_rasters

week = "2022_W11"

visual_compare_rasters(
    raster_path1=r"E:\ALIGNED\ToMODIS\GFSC\2022_W11.tif",
    raster_path2=r"E:\ALIGNED\ToMODIS\S2\2022_W11.tif",
    labels=(f"GFSC {week}", f"S2 {week}"),
    difference=True,
    downsample=5
)

# %%
from snow_processing import calculate_agreement
import rasterio
import numpy as np

rp1=r"F:\GeoinformaticsProject\Data\Processed\WEEKLY\MODIS\2022_W11.tif"
rp2=r"E:\ALIGNED\ToMODIS\GFSC\2022_W11.tif"

stats = calculate_agreement(rp1, rp2)
print(stats)

# and compute GFSC-only snow:
with rasterio.open(rp1) as m, rasterio.open(rp2) as g:
    m1 = m.read(1)==1
    g1 = g.read(1)==1
    gfsc_only = np.count_nonzero((~m1 & g1))
    modis_only= np.count_nonzero((m1 & ~g1))
    
print("GFSC-only snow pixels:", gfsc_only)
print("MODIS-only snow pixels:", modis_only)
# Out:
# {'agreement_pct': 0.0440161303016853, 'total_pixels': 751240506, 'agree_pixels': 330667}
# GFSC-only snow pixels: 1868867
# MODIS-only snow pixels: 575722515

# %%
from snow_processing import calculate_agreement
import rasterio
import numpy as np

rp1=r"E:\ALIGNED\ToMODIS\S2\2022_W11.tif"
rp2=r"E:\ALIGNED\ToMODIS\GFSC\2022_W11.tif"

stats = calculate_agreement(rp1, rp2)
print(stats)

# and compute GFSC-only snow:
with rasterio.open(rp1) as m, rasterio.open(rp2) as g:
    m1 = m.read(1)==1
    g1 = g.read(1)==1
    gfsc_only = np.count_nonzero((~m1 & g1))
    s2_only= np.count_nonzero((m1 & ~g1))
    
print("GFSC-only snow pixels:", gfsc_only)
print("S2-only snow pixels:", s2_only)
# Out:
# {'agreement_pct': 99.47613854877498, 'total_pixels': 630334985, 'agree_pixels': 627032903}
# GFSC-only snow pixels: 470626
# S2-only snow pixels: 3302082

# %%
import rasterio, numpy as np
with rasterio.open(r"F:\GeoinformaticsProject\Data\Processed\WEEKLY\MODIS\2023_W08.tif") as src:
    arr = src.read(1)
    print(np.unique(arr)[:10])  # first few unique values
# Out:
# [0 1]

# %%
import rasterio, numpy as np
with rasterio.open(r"F:\GeoinformaticsProject\Data\Processed\ALIGNED\ToMODIS\GFSC\2023_W08.tif") as src:
    arr = src.read(1)
    print(np.unique(arr)[:10])  # first few unique values
# Out:
# [0 1]

# %%
import rasterio, numpy as np
with rasterio.open(r"F:\GeoinformaticsProject\Data\Processed\ALIGNED\ToMODIS\S2\2023_W08.tif") as src:
    arr = src.read(1)
    print(np.unique(arr)[:10])  # first few unique values
# Out:
# [0 1]

# %%
import rasterio, numpy as np
with rasterio.open(r"F:\GeoinformaticsProject\Data\Processed\ALIGNED\ToMODIS\S3\2023_W08.tif") as src:
    arr = src.read(1)
    print(np.unique(arr)[:10])  # first few unique values
# Out:
# [0 1]

# %%
# ─────────────────────────────────────────────────────────────────────────────
# 1.  QUICK  DIAGNOSTICS  FOR  ONE  WEEK   (works with any two rasters)
# -----------------------------------------------------------------------------
import rasterio
import numpy as np
import pandas as pd

def raster_quick_stats(path):
    """Return nodata value, unique values and counts (clipped to 20 entries)."""
    with rasterio.open(path) as src:
        data = src.read(1)
        nodata = src.nodata
    # count occurrences
    vals, counts = np.unique(data, return_counts=True)
    tbl = pd.DataFrame({"value": vals, "count": counts})
    return nodata, tbl.head(20)

# ➤  provide the paths you just used in visual_compare_rasters_strict
week   = "2023_W08"
modis  = fr"F:\GeoinformaticsProject\Data\Processed\WEEKLY\MODIS\2023_W08.tif"
gfsc   = fr"F:\GeoinformaticsProject\Data\Processed\ALIGNED\ToMODIS\GFSC\2023_W08.tif"
s2     = fr"F:\GeoinformaticsProject\Data\Processed\ALIGNED\ToMODIS\S2\2023_W08.tif"
s3     = fr"F:\GeoinformaticsProject\Data\Processed\ALIGNED\ToMODIS\S3\2023_W08.tif"

for name, path in [("MODIS", modis), ("GFSC", gfsc), ("S2", s2), ("S3", s3)]:
    nodata, head = raster_quick_stats(path)
    print(f"\n{name}  ─ nodata = {nodata}")
    print(head)

# ─────────────────────────────────────────────────────────────────────────────
# 2.  CHECK  THAT  ALL  DATASETS  OVERLAP  AFTER  ALIGNMENT
# -----------------------------------------------------------------------------
from rasterio.windows import from_bounds

def intersection_bounds(src1, src2):
    minx = max(src1.bounds.left,   src2.bounds.left)
    miny = max(src1.bounds.bottom, src2.bounds.bottom)
    maxx = min(src1.bounds.right,  src2.bounds.right)
    maxy = min(src1.bounds.top,    src2.bounds.top)
    if (minx >= maxx) or (miny >= maxy):
        return None
    return (minx, miny, maxx, maxy)

with rasterio.open(modis) as m, rasterio.open(gfsc) as g:
    inter = intersection_bounds(m, g)
    print("\nMODIS vs GFSC intersection:", inter)
    if inter is not None:
        win = from_bounds(*inter, transform=m.transform)
        print("→ pixel window size (rows, cols):", (win.height, win.width))
# Out:
# MODIS  ─ nodata = None
#    value      count
# 0      0      63960
# 1      1  751176546
#
# GFSC  ─ nodata = None
#    value      count
# 0      0  629190795
# 1      1  122049711
#
# S2  ─ nodata = None
#    value      count
# 0      0  745954998
# 1      1    5285508
#
# S3  ─ nodata = None
#    value      count
# 0      0  744832056
# 1      1    6408450
#
# MODIS vs GFSC intersection: (299725.1480286992, 4799686.739310687, 900165.1480286992, 5300146.739310687)
# → pixel window size (rows, cols): (np.float64(25023.0), np.float64(30022.000000000007))

# %%
# --- user parameters ---
week     = "2023_W08"
modis    = fr"F:\GeoinformaticsProject\Data\Processed\WEEKLY\MODIS\2023_W08.tif"
gfsc     = fr"F:\GeoinformaticsProject\Data\Processed\ALIGNED\ToMODIS\GFSC\2023_W08.tif"
s2       = fr"F:\GeoinformaticsProject\Data\Processed\ALIGNED\ToMODIS\S2\2023_W08.tif"
s3       = fr"F:\GeoinformaticsProject\Data\Processed\ALIGNED\ToMODIS\S3\2023_W08.tif"

from snow_processing import visual_compare_rasters_strict

# ── MODIS vs GFSC ──────────────────────────────────────────
visual_compare_rasters_strict(
    raster_path1 = modis,
    raster_path2 = gfsc,
    labels       = (f"MODIS {week}", f"GFSC {week}"),
    difference   = True,   # set False for side‑by‑side
    downsample   = 5
)

# ── MODIS vs S2 ────────────────────────────────────────────
visual_compare_rasters_strict(
    raster_path1 = modis,
    raster_path2 = s2,
    labels       = (f"MODIS {week}", f"S2 {week}"),
    difference   = True,
    downsample   = 5
)

# ── MODIS vs S3 ────────────────────────────────────────────
visual_compare_rasters_strict(
    raster_path1 = modis,
    raster_path2 = s3,
    labels       = (f"MODIS {week}", f"S3 {week}"),
    difference   = True,
    downsample   = 5
)
# Out:
# f:\GeoinformaticsProject\Code\snow_processing.py:47: SyntaxWarning: invalid escape sequence '\M'
#   """

# %%
# Batch Comparison (Difference Map Viewer)

from snow_processing import visual_compare_rasters

# List all aligned GFSC files
for filename in os.listdir(output_dir):
    if filename.endswith(".tif"):
        week = filename.split("_")[1]  # extract '2022_W06' from 'GFSC_2022_W06_aligned.tif'
        modis_path = os.path.join(modis_dir, f"{week}.tif")
        gfsc_path = os.path.join(output_dir, filename)

        if os.path.exists(modis_path):
            print(f"🔍 Comparing MODIS vs GFSC for {week}...")
            visual_compare_rasters(
                raster_path1=modis_path,
                raster_path2=gfsc_path,
                labels=(f"MODIS {week}", f"GFSC {week}"),
                difference=True,
                downsample=5
            )
